# %%
import matplotlib.pyplot as plt

# %%
plt.pie([10,20])
# Out:
# ([<matplotlib.patches.Wedge at 0x107e5f770>,
# ...
#  [Text(0.5499999702695115, 0.9526279613277875, ''),
#   Text(-0.5499998810780428, -0.9526280128224968, '')])

# %%
plt.pie([1,2, 1, 1]);

# %%
plt.bar([10,12],[5, 7]);
