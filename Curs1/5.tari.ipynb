# %%
import matplotlib.pyplot as plt
import csv

# %%
countries = []
population =[]

with open("tari.csv") as freader:
    csv_reader = csv.DictReader(freader)
    print(csv_reader)

    for row in csv_reader:
        countries.append(row["country"])
        population.append(int(row["population"]))
    print("Countries", countries)
    print("Population", population)
# Out:
# <csv.DictReader object at 0x10fbf1190>
# Countries ['Bangladesh', 'Brazil', 'China', 'India', 'Indonesia', 'Mexico', 'Nigeria', 'Pakistan', 'Russia', 'United States']
# Population [170, 213, 1411, 1378, 271, 126, 211, 225, 146, 331]

# %%
plt.pie(population);

# %%
plt.title("Population of 10 biggest countries")
plt.pie(population, labels=countries);
plt.savefig("10_tari.png")
